# %% [markdown]
# # Job – Ingestão Yellow Taxi (Bronze)
#
# ## Tipo
# Scheduled Job
#
# ## Frequência
# - A cada 1 minuto (teste)
# - Em produção: diário
#
# ## Notebook executado
# notebooks/01_ingestao_bronze.py
#
# ## Parâmetros
# - Nenhum (controle feito via tabela tb_ctrl_ingestao_raw_bronze)
#
# ## Lógica
# - Consulta tabela de controle
# - Processa próximo ano disponível
# - Grava em bronze.yellow_taxi
# - Atualiza tabela de controle
#
# ## Observações
# - Job id configurado manualmente via UI
