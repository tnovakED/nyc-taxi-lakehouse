# %%
# %sql

-- Criano a tabela de controle para o fluxo do job para injestao de cada ano
CREATE TABLE IF NOT EXISTS nyc_taxi_catalog.bronze.tb_ctrl_ingestao_raw_bronze(
  dataset STRING,
  last_year INT,
  update_at TIMESTAMP
);

--inserção manual por ser um conjunto de dados pequeno

INSERT INTO nyc_taxi_catalog.bronze.tb_ctrl_ingestao_raw_bronze VALUES
('yellow_taxi',2022, current_timestamp)

# %%
# %sql
DROP TABLE IF EXISTS nyc_taxi_catalog.bronze.tb_ctrl_ingestao_raw_bronze

# %%
# %sql
SELECT
  year,
  COUNT(*) AS qtd_registros
FROM nyc_taxi_catalog.bronze.yellow_taxi
GROUP BY year
ORDER BY year;
